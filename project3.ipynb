# %% [markdown]
# **Import dataset**

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the dataset**

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Satistical Analysis

# %% [markdown]
# **Sepal Length**

# %%
from scipy import stats
mean = np.mean(df['sepal_length'])
print("Mean", mean)
# Out:
# Mean 5.843333333333334

# %%
median = np.median(df['sepal_length'])
print("Median", median)
# Out:
# Median 5.8

# %%
mode = stats.mode(df['sepal_length'])
print("Mode", mode.mode[0])
# Out:
# Mode 5.0
# C:\Users\dafin\AppData\Local\Temp\ipykernel_15620\2918714448.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['sepal_length'])

# %%
std = np.std(df['sepal_length'])
print("Standard Deviation", std)
# Out:
# Standard Deviation 0.8253012917851409

# %%
variance = np.var(df['sepal_length'])
print("Variance", variance)
# Out:
# Variance 0.6811222222222223

# %%
min = np.min(df['sepal_length'])
print("minimum",min )
# Out:
# minimum 4.3

# %%
max = np.max(df['sepal_length'])
print("maximum:", max)
# Out:
# maximum: 7.9

# %% [markdown]
# **Sepal Width**

# %%
mean = np.mean(df['sepal_width'])
print("Mean", mean)
# Out:
# Mean: 3.0573333333333337
# Median: 3.0
# Mode: 3.0
# Standard Deviation: 0.4344109677354946
# Variance: 0.1887128888888889
# min: 2.0
# max: 4.4
# C:\Users\dafin\AppData\Local\Temp\ipykernel_3256\872828060.py:7: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['sepal_width'])

# %%
median = np.median(df['sepal_width'])
print("Median", median)
# Out:
# Median 3.0

# %%
mode = stats.mode(df['sepal_width'])
print("Mode:", mode.mode[0])
# Out:
# Mode: 3.0
# C:\Users\dafin\AppData\Local\Temp\ipykernel_15620\1832721138.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['sepal_width'])

# %%
std = np.std(df['sepal_width'])
print("Standard Deviation:", std)
# Out:
# Standard Deviation: 0.4344109677354946

# %%
variance = np.var(df['sepal_width'])
print("Variance:", variance)
# Out:
# Variance: 0.1887128888888889

# %%
min = np.min(df['sepal_width'])
print("min:",min )
# Out:
# min: 2.0

# %%
max = np.max(df['sepal_width'])
print("max:", max)
# Out:
# max: 4.4

# %% [markdown]
# **Petal Length**

# %%
mean = np.mean(df['petal_length'])
print("Mean:", mean)
# Out:
# Mean: 3.7580000000000005

# %%
median = np.median(df['petal_length'])
print("Median:", median)
# Out:
# Median: 4.35

# %%
mode = stats.mode(df['petal_length'])
print("Mode:", mode.mode[0])
# Out:
# Mode: 1.4
# C:\Users\dafin\AppData\Local\Temp\ipykernel_15620\3945715975.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['petal_length'])

# %%
std = np.std(df['petal_length'])
print("Standard Deviation:", std)
# Out:
# Standard Deviation: 1.759404065775303

# %%
variance = np.var(df['petal_length'])
print("Variance:", variance)
# Out:
# Variance: 3.0955026666666665

# %%
min = np.min(df['petal_length'])
print("min:",min )
# Out:
# min: 1.0

# %%
max = np.max(df['petal_length'])
print("max:", max)
# Out:
# max: 6.9

# %% [markdown]
# **Petal Width**`

# %%
mean = np.mean(df['petal_width'])
print("Mean:", mean)
# Out:
# Mean: 1.1993333333333336

# %%
median = np.median(df['petal_width'])
print("Median:", median)
# Out:
# Median: 1.3

# %%
mode = stats.mode(df['petal_width'])
print("Mode:", mode.mode[0])
# Out:
# Mode: 0.2
# C:\Users\dafin\AppData\Local\Temp\ipykernel_15620\4290634674.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['petal_width'])

# %%
std = np.std(df['petal_width'])
print("Standard Deviation:", std)
# Out:
# Standard Deviation: 0.7596926279021594

# %%
variance = np.var(df['petal_width'])
print("Variance:", variance)
# Out:
# Variance: 0.5771328888888888

# %%
min = np.min(df['petal_width'])
print("min:",min )
# Out:
# min: 0.1

# %%
max = np.max(df['petal_width'])
print("max:", max)
# Out:
# max: 2.5

# %% [markdown]
# **Standard Deviation Plot**

# %%
sns.barplot(df.std(), color='b')
sns.set_style('darkgrid')
plt.title('Standard Deviation of Iris Dataset')
plt.ylabel('Standard Deviation')
plt.show()
# Out:
# C:\Users\dafin\AppData\Local\Temp\ipykernel_15620\2988716458.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.barplot(df.std(), color='b')

# %% [markdown]
# # IQR

# %% [markdown]
# # Sepal_length iqr

# %%
q1_sl=df.sepal_length.quantile(0.25)
q3_sl=df.sepal_length.quantile(0.75)
iqr_sl=q3_sl-q1_sl
iqr_sl
# Out:
# 1.3000000000000007

# %% [markdown]
# # Sepal_width iqr

# %%
q1_sw=df.sepal_width.quantile(0.25)
q3_sw=df.sepal_width.quantile(0.75)
iqr_sw=q3_sw-q1_sw
iqr_sw
# Out:
# 0.5

# %% [markdown]
# # petal_length iqr

# %%
q1_pl=df.petal_length.quantile(0.25)
q3_pl=df.petal_length.quantile(0.75)
iqr_pl=q3_pl-q1_pl
iqr_pl
# Out:
# 3.4999999999999996

# %% [markdown]
# # petal_width iqr

# %%
q1_pw=df.petal_width.quantile(0.25)
q3_pw=df.petal_width.quantile(0.75)
iqr_pw=q3_pw-q1_pw
iqr_pw
# Out:
# 1.5

# %% [markdown]
# # Outlier detection

# %% [markdown]
# # outlier detection in sepal length

# %%
UW=q3_sl +1.5 *iqr_sl
UW
LW=q1_sl-1.5*iqr_sl
LW
l=df['sepal_length']<LW
l_count=l.sum()
u=df['sepal_length']>UW
u_count=u.sum()
outlier=((df['sepal_length']<LW)|(df['sepal_length']>UW))
outlier.sum()
# Out:
# 0

# %% [markdown]
# # outlier detection in sepal width

# %%
UW=q3_sw +1.5 *iqr_sw
UW
LW=q1_sw-1.5*iqr_sw
LW
l=df['sepal_width']<LW
l_count=l.sum()
u=df['sepal_width']>UW
u_count=u.sum()
outlier=((df['sepal_width']<LW)|(df['sepal_width']>UW))
outlier.sum()
# Out:
# 4

# %% [markdown]
# # outlier detection in petal length

# %%
UW=q3_pl +1.5 *iqr_sw
UW
LW=q1_pl-1.5*iqr_sw
LW
l=df['petal_length']<LW
l_count=l.sum()
u=df['petal_length']>UW
u_count=u.sum()
outlier=((df['petal_length']<LW)|(df['petal_width']>UW))
outlier.sum()
# Out:
# 0

# %% [markdown]
# # outlier detection in petal width

# %%
UW=q3_pw +1.5 *iqr_sw
UW
LW=q1_pw-1.5*iqr_sw
LW
l=df['petal_width']<LW
l_count=l.sum()
u=df['petal_width']>UW
u_count=u.sum()
outlier=((df['petal_width']<LW)|(df['petal_width']>UW))
outlier.sum()
# Out:
# 0

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df= sns.load_dataset('iris')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='species',y='sepal_length',data=df)
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# # linear regression

# %%
sns.lmplot(x='petal_length',y='petal_width',data=df)

# %%
sns.lmplot(x='petal_length',y='petal_width',data=df,hue='species')

# %% [markdown]
# # scatter plot

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,hue='species',kind='scatter')

# %%
sns.pairplot(df,hue='species')

# %% [markdown]
# # Histogram

# %%
fig, ax = plt.subplots()
ax.hist(df['sepal_length'], bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['sepal_width'], bins=10)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['petal_length'], bins=10)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['petal_width'], bins=10)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)
